# %% [markdown]
# # Notebook to build an enriched case log from an event log

# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# ## 0. Data loading

# %%
INPUT_FILE_NAME = 'rtfm_full.csv' # a csv version of https://doi.org/10.4121/uuid:270fd440-1057-4fb9-89a9-b699b47990f5
CASE_ID_COL = 'case:concept:name'
TIMESTAMP_COL = 'time:timestamp'
ACTIVITY_COL = 'concept:name'

# %%
df = pd.read_csv(INPUT_FILE_NAME,  dtype={'org:resource': str, 'matricola': str}, parse_dates=[TIMESTAMP_COL])
print(len(df), 'rows read from', INPUT_FILE_NAME)
df = df.sort_values(TIMESTAMP_COL, ignore_index=True)
df.info()
df.head()
# Out:
# 561470 rows read from rtfm_full.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561470 entries, 0 to 561469
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   amount                230230 non-null  float64
#  1   org:resource          150925 non-null  object
#  2   dismissal             155066 non-null  object
#  3   concept:name          561470 non-null  object
#  4   vehicleClass          150370 non-null  object
#  5   totalPaymentAmount    227971 non-null  float64
#  6   lifecycle:transition  561470 non-null  object
#  7   time:timestamp        561470 non-null  datetime64[ns]
#  8   article               150370 non-null  float64
#  9   points                150370 non-null  float64
#  10  case:concept:name     561470 non-null  object
#  11  expense               103987 non-null  float64
#  12  notificationType      79860 non-null   object
#  13  lastSent              78229 non-null   object
#  14  paymentAmount         77601 non-null   float64
#  15  matricola             555 non-null     object
# dtypes: datetime64[ns](1), float64(6), object(9)
# memory usage: 68.5+ MB
#    amount org:resource dismissal concept:name vehicleClass
# 0   62.59           18       NIL  Create Fine            A  \
# 1   62.59          704       NIL  Create Fine            A
# 2   31.30           35       NIL  Create Fine            A
# 3   31.30           35       NIL  Create Fine            A
# 4   31.30           35       NIL  Create Fine            A
#
#    totalPaymentAmount lifecycle:transition time:timestamp  article  points
# 0                 0.0             complete     2000-01-01    158.0     0.0  \
# 1                 0.0             complete     2000-01-02    158.0     0.0
# 2                 0.0             complete     2000-01-02    158.0     0.0
# 3                 0.0             complete     2000-01-02    158.0     0.0
# 4                 0.0             complete     2000-01-02    158.0     0.0
#
#   case:concept:name  expense notificationType lastSent  paymentAmount
# 0            S38735      NaN              NaN      NaN            NaN  \
# 1            S44306      NaN              NaN      NaN            NaN
# 2            S49055      NaN              NaN      NaN            NaN
# 3            S49056      NaN              NaN      NaN            NaN
# 4            S49057      NaN              NaN      NaN            NaN
#
#   matricola
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %% [markdown]
# ## 1. Event enrichment

# %%
HIGHFLOAT = 2000000.0
# 1. Case History Aggregation: keep track of current state of a variable trough history of a case
TRACK = [
    ('amount', 'last', 0.0),
    ('amount', 'min', HIGHFLOAT),
    # ('totalPaymentAmount', 'max', 0.0), # uncomment to check the issues with totalPaymentAmount
    ('paymentAmount', 'sum', 0.0),
    ('dismissal', 'last', 'missing'),
    ('expense', 'sum', 0.0)
    ]
# 2. Add variables derived from other values of a row (i.e. event)
COMPUTE = [
    ('outstanding_balance', lambda x: round(x['amount::last'] + x['expense::sum'] - x['paymentAmount::sum'], 2)),
    ('outstanding_balance_without_expense', lambda x: round(x['amount::last'] - x['paymentAmount::sum'], 2)),
    ('outstanding_balance_without_penalty', lambda x: round(x['amount::min'] + x['expense::sum'] - x['paymentAmount::sum'], 2))
]

value_store = {} # map each tracked variable (incl method) and case to its current value
added_cols = {} # map each tracked variable (incl method) to a growing list/vector of values
added_col_names = []

for (col, method, _) in TRACK:
    added_cols[(col, method)] = []

for index, row in df.iterrows():
    case_id = row[CASE_ID_COL]
    for (col, method, init_val) in TRACK:
        if not (case_id, col, method) in value_store:
            value_store[(case_id, col, method)] = init_val
        if not pd.isna(row[col]):
            if method == 'last':
                value_store[(case_id, col, method)] = row[col]
            elif method == 'max':
                value_store[(case_id, col, method)] = max(row[col],value_store[(case_id, col, method)])
            elif method == 'min':
                value_store[(case_id, col, method)] = min(row[col],value_store[(case_id, col, method)])
            elif method == 'sum':
                value_store[(case_id, col, method)] = round(value_store[(case_id, col, method)] + row[col], 2)
            else:
                print('NOT SUPPORTED')
        added_cols[(col, method)].append(value_store[(case_id, col, method)])

for (col, method, _) in TRACK:
    tracking_col_name = col+'::'+method
    added_col_names.append(tracking_col_name)
    df[tracking_col_name] = added_cols[(col,method)]
        

for (name, function) in COMPUTE:
    added_col_names.append(name)
    df[name] = df.apply(function, axis=1)

# %%
intermediate_file_name = 'X' + INPUT_FILE_NAME
df.to_csv(intermediate_file_name, index=False)
print(len(df), 'rows written to', intermediate_file_name)
df.info()
df.head()
# Out:
# 561470 rows written to Xrtfm_full.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561470 entries, 0 to 561469
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   amount                               230230 non-null  float64
#  1   org:resource                         150925 non-null  object
#  2   dismissal                            155066 non-null  object
#  3   concept:name                         561470 non-null  object
#  4   vehicleClass                         150370 non-null  object
#  5   totalPaymentAmount                   227971 non-null  float64
#  6   lifecycle:transition                 561470 non-null  object
#  7   time:timestamp                       561470 non-null  datetime64[ns]
#  8   article                              150370 non-null  float64
#  9   points                               150370 non-null  float64
#  10  case:concept:name                    561470 non-null  object
#  11  expense                              103987 non-null  float64
#  12  notificationType                     79860 non-null   object
#  13  lastSent                             78229 non-null   object
#  14  paymentAmount                        77601 non-null   float64
#  15  matricola                            555 non-null     object
#  16  amount::last                         561470 non-null  float64
#  17  amount::min                          561470 non-null  float64
#  18  paymentAmount::sum                   561470 non-null  float64
#  19  dismissal::last                      561470 non-null  object
#  20  expense::sum                         561470 non-null  float64
#  21  outstanding_balance                  561470 non-null  float64
#  22  outstanding_balance_without_expense  561470 non-null  float64
#  23  outstanding_balance_without_penalty  561470 non-null  float64
# dtypes: datetime64[ns](1), float64(13), object(10)
# memory usage: 102.8+ MB
#    amount org:resource dismissal concept:name vehicleClass
# 0   62.59           18       NIL  Create Fine            A  \
# 1   62.59          704       NIL  Create Fine            A
# 2   31.30           35       NIL  Create Fine            A
# 3   31.30           35       NIL  Create Fine            A
# 4   31.30           35       NIL  Create Fine            A
#
#    totalPaymentAmount lifecycle:transition time:timestamp  article  points
# 0                 0.0             complete     2000-01-01    158.0     0.0  \
# 1                 0.0             complete     2000-01-02    158.0     0.0
# 2                 0.0             complete     2000-01-02    158.0     0.0
# 3                 0.0             complete     2000-01-02    158.0     0.0
# 4                 0.0             complete     2000-01-02    158.0     0.0
#
#    ... paymentAmount  matricola amount::last amount::min  paymentAmount::sum
# 0  ...           NaN        NaN        62.59       62.59                 0.0  \
# 1  ...           NaN        NaN        62.59       62.59                 0.0
# 2  ...           NaN        NaN        31.30       31.30                 0.0
# 3  ...           NaN        NaN        31.30       31.30                 0.0
# 4  ...           NaN        NaN        31.30       31.30                 0.0
#
#   dismissal::last  expense::sum  outstanding_balance
# 0             NIL           0.0                62.59  \
# 1             NIL           0.0                62.59
# 2             NIL           0.0                31.30
# 3             NIL           0.0                31.30
# 4             NIL           0.0                31.30
#
#    outstanding_balance_without_expense outstanding_balance_without_penalty
# 0                                62.59                               62.59
# 1                                62.59                               62.59
# 2                                31.30                               31.30
# 3                                31.30                               31.30
# 4                                31.30                               31.30
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 2. Case attributes

# %%
# Configure the number of attributes to be included
INCLUDE_DATA = True
INCLUDE_TIME = True
INCLUDE_DELAYS = True

# %%
# Create a case attribute from the value of that variable at the final event in a case
TAKE_AT_FINAL = added_col_names

case_index = {}
activity_list = []
log_starting_time = df.at[0, TIMESTAMP_COL]
print('log starting time:', log_starting_time)
columns = df.columns.to_list()
for col in [CASE_ID_COL, ACTIVITY_COL, TIMESTAMP_COL]:
    columns.remove(col)
for index, row in df.iterrows():
    case_id = row[CASE_ID_COL]
    activity_name = row[ACTIVITY_COL]
    if not activity_name in activity_list:
        activity_list.append(activity_name)
    qualifier = activity_name + '.'
    if not case_id in case_index:
        case_record = {'case_id': case_id, qualifier+'count': 1, 'event_count': 1}
        if INCLUDE_TIME:
            case_record['start_time'] = row[TIMESTAMP_COL]
            case_record['start_time_rel'] = int((row[TIMESTAMP_COL]-log_starting_time).components.days)
            case_record['duration'] = 0
            case_record[qualifier+'start'] = 0
        for col in columns:
            if not pd.isna(row[col]):
                if INCLUDE_DATA:
                    case_record[qualifier+col] = row[col]
                if col in TAKE_AT_FINAL:
                    field_name = 'Final.' + col
                    case_record[field_name] = row[col]
        case_index[case_id] = case_record
    else:
        case_record = case_index[case_id]
        case_record['event_count'] += 1
        if qualifier+'start' in case_record:
            # print('Activity {} occurs multiple times in case {}.'.format(activity_name, case_id))
            activity_count = case_record[qualifier+'count'] + 1
            case_record[qualifier+'count'] = activity_count
            qualifier = activity_name + ':' + str(activity_count) + '.'
        else:
            case_record[qualifier+'count'] = 1

        if INCLUDE_TIME:
            duration = row[TIMESTAMP_COL] - case_record['start_time']
            case_record[qualifier+'start'] = int(duration.components.days)  # str()
            case_record['duration'] = int(duration.components.days)  # duration
        for col in columns:
            if not pd.isna(row[col]):
                if INCLUDE_DATA:
                    case_record[qualifier+col] = row[col]
                if col in TAKE_AT_FINAL:
                    field_name = 'Final.' + col
                    case_record[field_name] = row[col]

out_df = pd.DataFrame([case_index[case_id] for case_id in case_index])

# Fill nan counts with 0
for col in out_df.columns:
    if col.endswith('.count'):
        out_df[col] = out_df[col].fillna(0)

# Add delay for each pair of distinct activities
if INCLUDE_DELAYS:
    first_activities = activity_list.copy()
    while len(first_activities) > 0:
        first_act = first_activities.pop()
        second_activities = first_activities.copy()
        while len(second_activities) > 0:
            second_act = second_activities.pop()
            column_name = first_act + ':' + second_act + '.delay'
            # print('adding', column_name)
            out_df[column_name] = out_df[second_act+'.start'] - out_df[first_act+'.start']

out_df.info(verbose=True)
# Out:
# log starting time: 2000-01-01 00:00:00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150370 entries, 0 to 150369
# Data columns (total 374 columns):
#  #    Column                                                                        Dtype
# ---   ------                                                                        -----
#  0    case_id                                                                       object
#  1    Create Fine.count                                                             int64
#  2    event_count                                                                   int64
#  3    start_time                                                                    datetime64[ns]
#  4    start_time_rel                                                                int64
#  5    duration                                                                      int64
#  6    Create Fine.start                                                             int64
#  7    Create Fine.amount                                                            float64
#  8    Create Fine.org:resource                                                      object
#  9    Create Fine.dismissal                                                         object
#  10   Create Fine.vehicleClass                                                      object
#  11   Create Fine.totalPaymentAmount                                                float64
#  12   Create Fine.lifecycle:transition                                              object
#  13   Create Fine.article                                                           float64
#  14   Create Fine.points                                                            float64
#  15   Create Fine.amount::last                                                      float64
#  16   Final.amount::last                                                            float64
#  17   Create Fine.amount::min                                                       float64
#  18   Final.amount::min                                                             float64
#  19   Create Fine.paymentAmount::sum                                                float64
#  20   Final.paymentAmount::sum                                                      float64
#  21   Create Fine.dismissal::last                                                   object
#  22   Final.dismissal::last                                                         object
#  23   Create Fine.expense::sum                                                      float64
#  24   Final.expense::sum                                                            float64
#  25   Create Fine.outstanding_balance                                               float64
#  26   Final.outstanding_balance                                                     float64
#  27   Create Fine.outstanding_balance_without_expense                               float64
#  28   Final.outstanding_balance_without_expense                                     float64
#  29   Create Fine.outstanding_balance_without_penalty                               float64
#  30   Final.outstanding_balance_without_penalty                                     float64
#  31   Send Fine.count                                                               float64
#  32   Send Fine.start                                                               float64
#  33   Send Fine.lifecycle:transition                                                object
#  34   Send Fine.expense                                                             float64
#  35   Send Fine.amount::last                                                        float64
#  36   Send Fine.amount::min                                                         float64
#  37   Send Fine.paymentAmount::sum                                                  float64
#  38   Send Fine.dismissal::last                                                     object
#  39   Send Fine.expense::sum                                                        float64
#  40   Send Fine.outstanding_balance                                                 float64
#  41   Send Fine.outstanding_balance_without_expense                                 float64
#  42   Send Fine.outstanding_balance_without_penalty                                 float64
#  43   Insert Fine Notification.count                                                float64
#  44   Insert Fine Notification.start                                                float64
#  45   Insert Fine Notification.lifecycle:transition                                 object
#  46   Insert Fine Notification.notificationType                                     object
#  47   Insert Fine Notification.lastSent                                             object
#  48   Insert Fine Notification.amount::last                                         float64
#  49   Insert Fine Notification.amount::min                                          float64
#  50   Insert Fine Notification.paymentAmount::sum                                   float64
#  51   Insert Fine Notification.dismissal::last                                      object
#  52   Insert Fine Notification.expense::sum                                         float64
#  53   Insert Fine Notification.outstanding_balance                                  float64
#  54   Insert Fine Notification.outstanding_balance_without_expense                  float64
#  55   Insert Fine Notification.outstanding_balance_without_penalty                  float64
#  56   Add penalty.count                                                             float64
#  57   Add penalty.start                                                             float64
#  58   Add penalty.amount                                                            float64
#  59   Add penalty.lifecycle:transition                                              object
#  60   Add penalty.amount::last                                                      float64
#  61   Add penalty.amount::min                                                       float64
#  62   Add penalty.paymentAmount::sum                                                float64
#  63   Add penalty.dismissal::last                                                   object
#  64   Add penalty.expense::sum                                                      float64
#  65   Add penalty.outstanding_balance                                               float64
#  66   Add penalty.outstanding_balance_without_expense                               float64
#  67   Add penalty.outstanding_balance_without_penalty                               float64
#  68   Send for Credit Collection.count                                              float64
#  69   Send for Credit Collection.start                                              float64
#  70   Send for Credit Collection.lifecycle:transition                               object
#  71   Send for Credit Collection.amount::last                                       float64
#  72   Send for Credit Collection.amount::min                                        float64
#  73   Send for Credit Collection.paymentAmount::sum                                 float64
#  74   Send for Credit Collection.dismissal::last                                    object
#  75   Send for Credit Collection.expense::sum                                       float64
#  76   Send for Credit Collection.outstanding_balance                                float64
#  77   Send for Credit Collection.outstanding_balance_without_expense                float64
#  78   Send for Credit Collection.outstanding_balance_without_penalty                float64
#  79   Payment.count                                                                 float64
#  80   Payment.start                                                                 float64
#  81   Payment.totalPaymentAmount                                                    float64
#  82   Payment.lifecycle:transition                                                  object
#  83   Payment.paymentAmount                                                         float64
#  84   Payment.amount::last                                                          float64
#  85   Payment.amount::min                                                           float64
#  86   Payment.paymentAmount::sum                                                    float64
#  87   Payment.dismissal::last                                                       object
#  88   Payment.expense::sum                                                          float64
#  89   Payment.outstanding_balance                                                   float64
#  90   Payment.outstanding_balance_without_expense                                   float64
#  91   Payment.outstanding_balance_without_penalty                                   float64
#  92   Payment:2.start                                                               float64
#  93   Payment:2.totalPaymentAmount                                                  float64
#  94   Payment:2.lifecycle:transition                                                object
#  95   Payment:2.paymentAmount                                                       float64
#  96   Payment:2.amount::last                                                        float64
#  97   Payment:2.amount::min                                                         float64
#  98   Payment:2.paymentAmount::sum                                                  float64
#  99   Payment:2.dismissal::last                                                     object
#  100  Payment:2.expense::sum                                                        float64
#  101  Payment:2.outstanding_balance                                                 float64
#  102  Payment:2.outstanding_balance_without_expense                                 float64
#  103  Payment:2.outstanding_balance_without_penalty                                 float64
#  104  Insert Date Appeal to Prefecture.count                                        float64
#  105  Insert Date Appeal to Prefecture.start                                        float64
#  106  Insert Date Appeal to Prefecture.lifecycle:transition                         object
#  107  Insert Date Appeal to Prefecture.amount::last                                 float64
#  108  Insert Date Appeal to Prefecture.amount::min                                  float64
#  109  Insert Date Appeal to Prefecture.paymentAmount::sum                           float64
#  110  Insert Date Appeal to Prefecture.dismissal::last                              object
#  111  Insert Date Appeal to Prefecture.expense::sum                                 float64
#  112  Insert Date Appeal to Prefecture.outstanding_balance                          float64
#  113  Insert Date Appeal to Prefecture.outstanding_balance_without_expense          float64
#  114  Insert Date Appeal to Prefecture.outstanding_balance_without_penalty          float64
#  115  Send Appeal to Prefecture.count                                               float64
#  116  Send Appeal to Prefecture.start                                               float64
#  117  Send Appeal to Prefecture.dismissal                                           object
#  118  Send Appeal to Prefecture.lifecycle:transition                                object
#  119  Send Appeal to Prefecture.amount::last                                        float64
#  120  Send Appeal to Prefecture.amount::min                                         float64
#  121  Send Appeal to Prefecture.paymentAmount::sum                                  float64
#  122  Send Appeal to Prefecture.dismissal::last                                     object
#  123  Send Appeal to Prefecture.expense::sum                                        float64
#  124  Send Appeal to Prefecture.outstanding_balance                                 float64
#  125  Send Appeal to Prefecture.outstanding_balance_without_expense                 float64
#  126  Send Appeal to Prefecture.outstanding_balance_without_penalty                 float64
#  127  Receive Result Appeal from Prefecture.count                                   float64
#  128  Receive Result Appeal from Prefecture.start                                   float64
#  129  Receive Result Appeal from Prefecture.lifecycle:transition                    object
#  130  Receive Result Appeal from Prefecture.amount::last                            float64
#  131  Receive Result Appeal from Prefecture.amount::min                             float64
#  132  Receive Result Appeal from Prefecture.paymentAmount::sum                      float64
#  133  Receive Result Appeal from Prefecture.dismissal::last                         object
#  134  Receive Result Appeal from Prefecture.expense::sum                            float64
#  135  Receive Result Appeal from Prefecture.outstanding_balance                     float64
#  136  Receive Result Appeal from Prefecture.outstanding_balance_without_expense     float64
#  137  Receive Result Appeal from Prefecture.outstanding_balance_without_penalty     float64
#  138  Notify Result Appeal to Offender.count                                        float64
#  139  Notify Result Appeal to Offender.start                                        float64
#  140  Notify Result Appeal to Offender.lifecycle:transition                         object
#  141  Notify Result Appeal to Offender.amount::last                                 float64
#  142  Notify Result Appeal to Offender.amount::min                                  float64
#  143  Notify Result Appeal to Offender.paymentAmount::sum                           float64
#  144  Notify Result Appeal to Offender.dismissal::last                              object
#  145  Notify Result Appeal to Offender.expense::sum                                 float64
#  146  Notify Result Appeal to Offender.outstanding_balance                          float64
#  147  Notify Result Appeal to Offender.outstanding_balance_without_expense          float64
#  148  Notify Result Appeal to Offender.outstanding_balance_without_penalty          float64
#  149  Appeal to Judge.count                                                         float64
#  150  Appeal to Judge.start                                                         float64
#  151  Appeal to Judge.org:resource                                                  object
#  152  Appeal to Judge.dismissal                                                     object
#  153  Appeal to Judge.lifecycle:transition                                          object
#  154  Appeal to Judge.matricola                                                     object
#  155  Appeal to Judge.amount::last                                                  float64
#  156  Appeal to Judge.amount::min                                                   float64
#  157  Appeal to Judge.paymentAmount::sum                                            float64
#  158  Appeal to Judge.dismissal::last                                               object
#  159  Appeal to Judge.expense::sum                                                  float64
#  160  Appeal to Judge.outstanding_balance                                           float64
#  161  Appeal to Judge.outstanding_balance_without_expense                           float64
#  162  Appeal to Judge.outstanding_balance_without_penalty                           float64
#  163  Payment:3.start                                                               float64
#  164  Payment:3.totalPaymentAmount                                                  float64
#  165  Payment:3.lifecycle:transition                                                object
#  166  Payment:3.paymentAmount                                                       float64
#  167  Payment:3.amount::last                                                        float64
#  168  Payment:3.amount::min                                                         float64
#  169  Payment:3.paymentAmount::sum                                                  float64
#  170  Payment:3.dismissal::last                                                     object
#  171  Payment:3.expense::sum                                                        float64
#  172  Payment:3.outstanding_balance                                                 float64
#  173  Payment:3.outstanding_balance_without_expense                                 float64
#  174  Payment:3.outstanding_balance_without_penalty                                 float64
#  175  Payment:4.start                                                               float64
#  176  Payment:4.totalPaymentAmount                                                  float64
#  177  Payment:4.lifecycle:transition                                                object
#  178  Payment:4.paymentAmount                                                       float64
#  179  Payment:4.amount::last                                                        float64
#  180  Payment:4.amount::min                                                         float64
#  181  Payment:4.paymentAmount::sum                                                  float64
#  182  Payment:4.dismissal::last                                                     object
#  183  Payment:4.expense::sum                                                        float64
#  184  Payment:4.outstanding_balance                                                 float64
#  185  Payment:4.outstanding_balance_without_expense                                 float64
#  186  Payment:4.outstanding_balance_without_penalty                                 float64
#  187  Payment:5.start                                                               float64
#  188  Payment:5.totalPaymentAmount                                                  float64
#  189  Payment:5.lifecycle:transition                                                object
#  190  Payment:5.paymentAmount                                                       float64
#  191  Payment:5.amount::last                                                        float64
#  192  Payment:5.amount::min                                                         float64
#  193  Payment:5.paymentAmount::sum                                                  float64
#  194  Payment:5.dismissal::last                                                     object
#  195  Payment:5.expense::sum                                                        float64
#  196  Payment:5.outstanding_balance                                                 float64
#  197  Payment:5.outstanding_balance_without_expense                                 float64
#  198  Payment:5.outstanding_balance_without_penalty                                 float64
#  199  Payment:6.start                                                               float64
#  200  Payment:6.totalPaymentAmount                                                  float64
#  201  Payment:6.lifecycle:transition                                                object
#  202  Payment:6.paymentAmount                                                       float64
#  203  Payment:6.amount::last                                                        float64
#  204  Payment:6.amount::min                                                         float64
#  205  Payment:6.paymentAmount::sum                                                  float64
#  206  Payment:6.dismissal::last                                                     object
#  207  Payment:6.expense::sum                                                        float64
#  208  Payment:6.outstanding_balance                                                 float64
#  209  Payment:6.outstanding_balance_without_expense                                 float64
#  210  Payment:6.outstanding_balance_without_penalty                                 float64
#  211  Payment:7.start                                                               float64
#  212  Payment:7.totalPaymentAmount                                                  float64
#  213  Payment:7.lifecycle:transition                                                object
#  214  Payment:7.paymentAmount                                                       float64
#  215  Payment:7.amount::last                                                        float64
#  216  Payment:7.amount::min                                                         float64
#  217  Payment:7.paymentAmount::sum                                                  float64
#  218  Payment:7.dismissal::last                                                     object
#  219  Payment:7.expense::sum                                                        float64
#  220  Payment:7.outstanding_balance                                                 float64
#  221  Payment:7.outstanding_balance_without_expense                                 float64
#  222  Payment:7.outstanding_balance_without_penalty                                 float64
#  223  Payment:8.start                                                               float64
#  224  Payment:8.totalPaymentAmount                                                  float64
#  225  Payment:8.lifecycle:transition                                                object
#  226  Payment:8.paymentAmount                                                       float64
#  227  Payment:8.amount::last                                                        float64
#  228  Payment:8.amount::min                                                         float64
#  229  Payment:8.paymentAmount::sum                                                  float64
#  230  Payment:8.dismissal::last                                                     object
#  231  Payment:8.expense::sum                                                        float64
#  232  Payment:8.outstanding_balance                                                 float64
#  233  Payment:8.outstanding_balance_without_expense                                 float64
#  234  Payment:8.outstanding_balance_without_penalty                                 float64
#  235  Payment:9.start                                                               float64
#  236  Payment:9.totalPaymentAmount                                                  float64
#  237  Payment:9.lifecycle:transition                                                object
#  238  Payment:9.paymentAmount                                                       float64
#  239  Payment:9.amount::last                                                        float64
#  240  Payment:9.amount::min                                                         float64
#  241  Payment:9.paymentAmount::sum                                                  float64
#  242  Payment:9.dismissal::last                                                     object
#  243  Payment:9.expense::sum                                                        float64
#  244  Payment:9.outstanding_balance                                                 float64
#  245  Payment:9.outstanding_balance_without_expense                                 float64
#  246  Payment:9.outstanding_balance_without_penalty                                 float64
#  247  Payment:10.start                                                              float64
#  248  Payment:10.totalPaymentAmount                                                 float64
#  249  Payment:10.lifecycle:transition                                               object
#  250  Payment:10.paymentAmount                                                      float64
#  251  Payment:10.amount::last                                                       float64
#  252  Payment:10.amount::min                                                        float64
#  253  Payment:10.paymentAmount::sum                                                 float64
#  254  Payment:10.dismissal::last                                                    object
#  255  Payment:10.expense::sum                                                       float64
#  256  Payment:10.outstanding_balance                                                float64
#  257  Payment:10.outstanding_balance_without_expense                                float64
#  258  Payment:10.outstanding_balance_without_penalty                                float64
#  259  Payment:11.start                                                              float64
#  260  Payment:11.totalPaymentAmount                                                 float64
#  261  Payment:11.lifecycle:transition                                               object
#  262  Payment:11.paymentAmount                                                      float64
#  263  Payment:11.amount::last                                                       float64
#  264  Payment:11.amount::min                                                        float64
#  265  Payment:11.paymentAmount::sum                                                 float64
#  266  Payment:11.dismissal::last                                                    object
#  267  Payment:11.expense::sum                                                       float64
#  268  Payment:11.outstanding_balance                                                float64
#  269  Payment:11.outstanding_balance_without_expense                                float64
#  270  Payment:11.outstanding_balance_without_penalty                                float64
#  271  Payment:12.start                                                              float64
#  272  Payment:12.totalPaymentAmount                                                 float64
#  273  Payment:12.lifecycle:transition                                               object
#  274  Payment:12.paymentAmount                                                      float64
#  275  Payment:12.amount::last                                                       float64
#  276  Payment:12.amount::min                                                        float64
#  277  Payment:12.paymentAmount::sum                                                 float64
#  278  Payment:12.dismissal::last                                                    object
#  279  Payment:12.expense::sum                                                       float64
#  280  Payment:12.outstanding_balance                                                float64
#  281  Payment:12.outstanding_balance_without_expense                                float64
#  282  Payment:12.outstanding_balance_without_penalty                                float64
#  283  Payment:13.start                                                              float64
#  284  Payment:13.totalPaymentAmount                                                 float64
#  285  Payment:13.lifecycle:transition                                               object
#  286  Payment:13.paymentAmount                                                      float64
#  287  Payment:13.amount::last                                                       float64
#  288  Payment:13.amount::min                                                        float64
#  289  Payment:13.paymentAmount::sum                                                 float64
#  290  Payment:13.dismissal::last                                                    object
#  291  Payment:13.expense::sum                                                       float64
#  292  Payment:13.outstanding_balance                                                float64
#  293  Payment:13.outstanding_balance_without_expense                                float64
#  294  Payment:13.outstanding_balance_without_penalty                                float64
#  295  Payment:14.start                                                              float64
#  296  Payment:14.totalPaymentAmount                                                 float64
#  297  Payment:14.lifecycle:transition                                               object
#  298  Payment:14.paymentAmount                                                      float64
#  299  Payment:14.amount::last                                                       float64
#  300  Payment:14.amount::min                                                        float64
#  301  Payment:14.paymentAmount::sum                                                 float64
#  302  Payment:14.dismissal::last                                                    object
#  303  Payment:14.expense::sum                                                       float64
#  304  Payment:14.outstanding_balance                                                float64
#  305  Payment:14.outstanding_balance_without_expense                                float64
#  306  Payment:14.outstanding_balance_without_penalty                                float64
#  307  Payment:15.start                                                              float64
#  308  Payment:15.totalPaymentAmount                                                 float64
#  309  Payment:15.lifecycle:transition                                               object
#  310  Payment:15.paymentAmount                                                      float64
#  311  Payment:15.amount::last                                                       float64
#  312  Payment:15.amount::min                                                        float64
#  313  Payment:15.paymentAmount::sum                                                 float64
#  314  Payment:15.dismissal::last                                                    object
#  315  Payment:15.expense::sum                                                       float64
#  316  Payment:15.outstanding_balance                                                float64
#  317  Payment:15.outstanding_balance_without_expense                                float64
#  318  Payment:15.outstanding_balance_without_penalty                                float64
#  319  Send for Credit Collection:Appeal to Judge.delay                              float64
#  320  Send for Credit Collection:Notify Result Appeal to Offender.delay             float64
#  321  Send for Credit Collection:Receive Result Appeal from Prefecture.delay        float64
#  322  Send for Credit Collection:Send Appeal to Prefecture.delay                    float64
#  323  Send for Credit Collection:Insert Date Appeal to Prefecture.delay             float64
#  324  Send for Credit Collection:Add penalty.delay                                  float64
#  325  Send for Credit Collection:Insert Fine Notification.delay                     float64
#  326  Send for Credit Collection:Send Fine.delay                                    float64
#  327  Send for Credit Collection:Payment.delay                                      float64
#  328  Send for Credit Collection:Create Fine.delay                                  float64
#  329  Appeal to Judge:Notify Result Appeal to Offender.delay                        float64
#  330  Appeal to Judge:Receive Result Appeal from Prefecture.delay                   float64
#  331  Appeal to Judge:Send Appeal to Prefecture.delay                               float64
#  332  Appeal to Judge:Insert Date Appeal to Prefecture.delay                        float64
#  333  Appeal to Judge:Add penalty.delay                                             float64
#  334  Appeal to Judge:Insert Fine Notification.delay                                float64
#  335  Appeal to Judge:Send Fine.delay                                               float64
#  336  Appeal to Judge:Payment.delay                                                 float64
#  337  Appeal to Judge:Create Fine.delay                                             float64
#  338  Notify Result Appeal to Offender:Receive Result Appeal from Prefecture.delay  float64
#  339  Notify Result Appeal to Offender:Send Appeal to Prefecture.delay              float64
#  340  Notify Result Appeal to Offender:Insert Date Appeal to Prefecture.delay       float64
#  341  Notify Result Appeal to Offender:Add penalty.delay                            float64
#  342  Notify Result Appeal to Offender:Insert Fine Notification.delay               float64
#  343  Notify Result Appeal to Offender:Send Fine.delay                              float64
#  344  Notify Result Appeal to Offender:Payment.delay                                float64
#  345  Notify Result Appeal to Offender:Create Fine.delay                            float64
#  346  Receive Result Appeal from Prefecture:Send Appeal to Prefecture.delay         float64
#  347  Receive Result Appeal from Prefecture:Insert Date Appeal to Prefecture.delay  float64
#  348  Receive Result Appeal from Prefecture:Add penalty.delay                       float64
#  349  Receive Result Appeal from Prefecture:Insert Fine Notification.delay          float64
#  350  Receive Result Appeal from Prefecture:Send Fine.delay                         float64
#  351  Receive Result Appeal from Prefecture:Payment.delay                           float64
#  352  Receive Result Appeal from Prefecture:Create Fine.delay                       float64
#  353  Send Appeal to Prefecture:Insert Date Appeal to Prefecture.delay              float64
#  354  Send Appeal to Prefecture:Add penalty.delay                                   float64
#  355  Send Appeal to Prefecture:Insert Fine Notification.delay                      float64
#  356  Send Appeal to Prefecture:Send Fine.delay                                     float64
#  357  Send Appeal to Prefecture:Payment.delay                                       float64
#  358  Send Appeal to Prefecture:Create Fine.delay                                   float64
#  359  Insert Date Appeal to Prefecture:Add penalty.delay                            float64
#  360  Insert Date Appeal to Prefecture:Insert Fine Notification.delay               float64
#  361  Insert Date Appeal to Prefecture:Send Fine.delay                              float64
#  362  Insert Date Appeal to Prefecture:Payment.delay                                float64
#  363  Insert Date Appeal to Prefecture:Create Fine.delay                            float64
#  364  Add penalty:Insert Fine Notification.delay                                    float64
#  365  Add penalty:Send Fine.delay                                                   float64
#  366  Add penalty:Payment.delay                                                     float64
#  367  Add penalty:Create Fine.delay                                                 float64
#  368  Insert Fine Notification:Send Fine.delay                                      float64
#  369  Insert Fine Notification:Payment.delay                                        float64
#  370  Insert Fine Notification:Create Fine.delay                                    float64
#  371  Send Fine:Payment.delay                                                       float64
#  372  Send Fine:Create Fine.delay                                                   float64
#  373  Payment:Create Fine.delay                                                     float64
# dtypes: datetime64[ns](1), float64(307), int64(5), object(61)
# memory usage: 429.1+ MB

# %% [markdown]
# ## 3. Case predicates from earlier analysis

# %%
# Add case predicates based on the existing case attributes, domain-specific through earlier analysis, e.g. in an outcome flow diagram
out_df['paid_full'] = out_df['Final.outstanding_balance'] <= 0.0
out_df['dismissed'] = out_df['Final.dismissal::last'].isin(['G', '#'])
out_df['credit_collection'] = out_df['Send for Credit Collection.count'] >= 1
out_df['unresolved'] = ~out_df['paid_full'] & ~out_df['credit_collection'] & ~out_df['dismissed']

# out_df['verify_0'] = (out_df['Final.totalPaymentAmount::max'] == out_df['Final.paymentAmount::sum'])
# out_df['verify_1'] = (out_df['Insert Fine Notification.count'] == out_df['Add penalty.count'])

out_df['appeal'] = (out_df['Appeal to Judge.count'] >= 1) | (out_df['Insert Date Appeal to Prefecture.count'] >= 1)
out_df['overturned_judge'] = (out_df['Appeal to Judge.count'] >= 1) & (out_df['Final.dismissal::last'] == 'G')
out_df['overturned_prefecture'] = (out_df['Insert Date Appeal to Prefecture.count'] >= 1) & (out_df['Final.dismissal::last'] == '#')
out_df['overturned'] = out_df['overturned_judge'] | out_df['overturned_prefecture']
out_df['upheld'] = out_df['appeal'] & ~out_df['overturned']

out_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150370 entries, 0 to 150369
# Data columns (total 383 columns):
#  #    Column                                                                        Dtype
# ---   ------                                                                        -----
#  0    case_id                                                                       object
#  1    Create Fine.count                                                             int64
#  2    event_count                                                                   int64
#  3    start_time                                                                    datetime64[ns]
#  4    start_time_rel                                                                int64
#  5    duration                                                                      int64
#  6    Create Fine.start                                                             int64
#  7    Create Fine.amount                                                            float64
#  8    Create Fine.org:resource                                                      object
#  9    Create Fine.dismissal                                                         object
#  10   Create Fine.vehicleClass                                                      object
#  11   Create Fine.totalPaymentAmount                                                float64
#  12   Create Fine.lifecycle:transition                                              object
#  13   Create Fine.article                                                           float64
#  14   Create Fine.points                                                            float64
#  15   Create Fine.amount::last                                                      float64
#  16   Final.amount::last                                                            float64
#  17   Create Fine.amount::min                                                       float64
#  18   Final.amount::min                                                             float64
#  19   Create Fine.paymentAmount::sum                                                float64
#  20   Final.paymentAmount::sum                                                      float64
#  21   Create Fine.dismissal::last                                                   object
#  22   Final.dismissal::last                                                         object
#  23   Create Fine.expense::sum                                                      float64
#  24   Final.expense::sum                                                            float64
#  25   Create Fine.outstanding_balance                                               float64
#  26   Final.outstanding_balance                                                     float64
#  27   Create Fine.outstanding_balance_without_expense                               float64
#  28   Final.outstanding_balance_without_expense                                     float64
#  29   Create Fine.outstanding_balance_without_penalty                               float64
#  30   Final.outstanding_balance_without_penalty                                     float64
#  31   Send Fine.count                                                               float64
#  32   Send Fine.start                                                               float64
#  33   Send Fine.lifecycle:transition                                                object
#  34   Send Fine.expense                                                             float64
#  35   Send Fine.amount::last                                                        float64
#  36   Send Fine.amount::min                                                         float64
#  37   Send Fine.paymentAmount::sum                                                  float64
#  38   Send Fine.dismissal::last                                                     object
#  39   Send Fine.expense::sum                                                        float64
#  40   Send Fine.outstanding_balance                                                 float64
#  41   Send Fine.outstanding_balance_without_expense                                 float64
#  42   Send Fine.outstanding_balance_without_penalty                                 float64
#  43   Insert Fine Notification.count                                                float64
#  44   Insert Fine Notification.start                                                float64
#  45   Insert Fine Notification.lifecycle:transition                                 object
#  46   Insert Fine Notification.notificationType                                     object
#  47   Insert Fine Notification.lastSent                                             object
#  48   Insert Fine Notification.amount::last                                         float64
#  49   Insert Fine Notification.amount::min                                          float64
#  50   Insert Fine Notification.paymentAmount::sum                                   float64
#  51   Insert Fine Notification.dismissal::last                                      object
#  52   Insert Fine Notification.expense::sum                                         float64
#  53   Insert Fine Notification.outstanding_balance                                  float64
#  54   Insert Fine Notification.outstanding_balance_without_expense                  float64
#  55   Insert Fine Notification.outstanding_balance_without_penalty                  float64
#  56   Add penalty.count                                                             float64
#  57   Add penalty.start                                                             float64
#  58   Add penalty.amount                                                            float64
#  59   Add penalty.lifecycle:transition                                              object
#  60   Add penalty.amount::last                                                      float64
#  61   Add penalty.amount::min                                                       float64
#  62   Add penalty.paymentAmount::sum                                                float64
#  63   Add penalty.dismissal::last                                                   object
#  64   Add penalty.expense::sum                                                      float64
#  65   Add penalty.outstanding_balance                                               float64
#  66   Add penalty.outstanding_balance_without_expense                               float64
#  67   Add penalty.outstanding_balance_without_penalty                               float64
#  68   Send for Credit Collection.count                                              float64
#  69   Send for Credit Collection.start                                              float64
#  70   Send for Credit Collection.lifecycle:transition                               object
#  71   Send for Credit Collection.amount::last                                       float64
#  72   Send for Credit Collection.amount::min                                        float64
#  73   Send for Credit Collection.paymentAmount::sum                                 float64
#  74   Send for Credit Collection.dismissal::last                                    object
#  75   Send for Credit Collection.expense::sum                                       float64
#  76   Send for Credit Collection.outstanding_balance                                float64
#  77   Send for Credit Collection.outstanding_balance_without_expense                float64
#  78   Send for Credit Collection.outstanding_balance_without_penalty                float64
#  79   Payment.count                                                                 float64
#  80   Payment.start                                                                 float64
#  81   Payment.totalPaymentAmount                                                    float64
#  82   Payment.lifecycle:transition                                                  object
#  83   Payment.paymentAmount                                                         float64
#  84   Payment.amount::last                                                          float64
#  85   Payment.amount::min                                                           float64
#  86   Payment.paymentAmount::sum                                                    float64
#  87   Payment.dismissal::last                                                       object
#  88   Payment.expense::sum                                                          float64
#  89   Payment.outstanding_balance                                                   float64
#  90   Payment.outstanding_balance_without_expense                                   float64
#  91   Payment.outstanding_balance_without_penalty                                   float64
#  92   Payment:2.start                                                               float64
#  93   Payment:2.totalPaymentAmount                                                  float64
#  94   Payment:2.lifecycle:transition                                                object
#  95   Payment:2.paymentAmount                                                       float64
#  96   Payment:2.amount::last                                                        float64
#  97   Payment:2.amount::min                                                         float64
#  98   Payment:2.paymentAmount::sum                                                  float64
#  99   Payment:2.dismissal::last                                                     object
#  100  Payment:2.expense::sum                                                        float64
#  101  Payment:2.outstanding_balance                                                 float64
#  102  Payment:2.outstanding_balance_without_expense                                 float64
#  103  Payment:2.outstanding_balance_without_penalty                                 float64
#  104  Insert Date Appeal to Prefecture.count                                        float64
#  105  Insert Date Appeal to Prefecture.start                                        float64
#  106  Insert Date Appeal to Prefecture.lifecycle:transition                         object
#  107  Insert Date Appeal to Prefecture.amount::last                                 float64
#  108  Insert Date Appeal to Prefecture.amount::min                                  float64
#  109  Insert Date Appeal to Prefecture.paymentAmount::sum                           float64
#  110  Insert Date Appeal to Prefecture.dismissal::last                              object
#  111  Insert Date Appeal to Prefecture.expense::sum                                 float64
#  112  Insert Date Appeal to Prefecture.outstanding_balance                          float64
#  113  Insert Date Appeal to Prefecture.outstanding_balance_without_expense          float64
#  114  Insert Date Appeal to Prefecture.outstanding_balance_without_penalty          float64
#  115  Send Appeal to Prefecture.count                                               float64
#  116  Send Appeal to Prefecture.start                                               float64
#  117  Send Appeal to Prefecture.dismissal                                           object
#  118  Send Appeal to Prefecture.lifecycle:transition                                object
#  119  Send Appeal to Prefecture.amount::last                                        float64
#  120  Send Appeal to Prefecture.amount::min                                         float64
#  121  Send Appeal to Prefecture.paymentAmount::sum                                  float64
#  122  Send Appeal to Prefecture.dismissal::last                                     object
#  123  Send Appeal to Prefecture.expense::sum                                        float64
#  124  Send Appeal to Prefecture.outstanding_balance                                 float64
#  125  Send Appeal to Prefecture.outstanding_balance_without_expense                 float64
#  126  Send Appeal to Prefecture.outstanding_balance_without_penalty                 float64
#  127  Receive Result Appeal from Prefecture.count                                   float64
#  128  Receive Result Appeal from Prefecture.start                                   float64
#  129  Receive Result Appeal from Prefecture.lifecycle:transition                    object
#  130  Receive Result Appeal from Prefecture.amount::last                            float64
#  131  Receive Result Appeal from Prefecture.amount::min                             float64
#  132  Receive Result Appeal from Prefecture.paymentAmount::sum                      float64
#  133  Receive Result Appeal from Prefecture.dismissal::last                         object
#  134  Receive Result Appeal from Prefecture.expense::sum                            float64
#  135  Receive Result Appeal from Prefecture.outstanding_balance                     float64
#  136  Receive Result Appeal from Prefecture.outstanding_balance_without_expense     float64
#  137  Receive Result Appeal from Prefecture.outstanding_balance_without_penalty     float64
#  138  Notify Result Appeal to Offender.count                                        float64
#  139  Notify Result Appeal to Offender.start                                        float64
#  140  Notify Result Appeal to Offender.lifecycle:transition                         object
#  141  Notify Result Appeal to Offender.amount::last                                 float64
#  142  Notify Result Appeal to Offender.amount::min                                  float64
#  143  Notify Result Appeal to Offender.paymentAmount::sum                           float64
#  144  Notify Result Appeal to Offender.dismissal::last                              object
#  145  Notify Result Appeal to Offender.expense::sum                                 float64
#  146  Notify Result Appeal to Offender.outstanding_balance                          float64
#  147  Notify Result Appeal to Offender.outstanding_balance_without_expense          float64
#  148  Notify Result Appeal to Offender.outstanding_balance_without_penalty          float64
#  149  Appeal to Judge.count                                                         float64
#  150  Appeal to Judge.start                                                         float64
#  151  Appeal to Judge.org:resource                                                  object
#  152  Appeal to Judge.dismissal                                                     object
#  153  Appeal to Judge.lifecycle:transition                                          object
#  154  Appeal to Judge.matricola                                                     object
#  155  Appeal to Judge.amount::last                                                  float64
#  156  Appeal to Judge.amount::min                                                   float64
#  157  Appeal to Judge.paymentAmount::sum                                            float64
#  158  Appeal to Judge.dismissal::last                                               object
#  159  Appeal to Judge.expense::sum                                                  float64
#  160  Appeal to Judge.outstanding_balance                                           float64
#  161  Appeal to Judge.outstanding_balance_without_expense                           float64
#  162  Appeal to Judge.outstanding_balance_without_penalty                           float64
#  163  Payment:3.start                                                               float64
#  164  Payment:3.totalPaymentAmount                                                  float64
#  165  Payment:3.lifecycle:transition                                                object
#  166  Payment:3.paymentAmount                                                       float64
#  167  Payment:3.amount::last                                                        float64
#  168  Payment:3.amount::min                                                         float64
#  169  Payment:3.paymentAmount::sum                                                  float64
#  170  Payment:3.dismissal::last                                                     object
#  171  Payment:3.expense::sum                                                        float64
#  172  Payment:3.outstanding_balance                                                 float64
#  173  Payment:3.outstanding_balance_without_expense                                 float64
#  174  Payment:3.outstanding_balance_without_penalty                                 float64
#  175  Payment:4.start                                                               float64
#  176  Payment:4.totalPaymentAmount                                                  float64
#  177  Payment:4.lifecycle:transition                                                object
#  178  Payment:4.paymentAmount                                                       float64
#  179  Payment:4.amount::last                                                        float64
#  180  Payment:4.amount::min                                                         float64
#  181  Payment:4.paymentAmount::sum                                                  float64
#  182  Payment:4.dismissal::last                                                     object
#  183  Payment:4.expense::sum                                                        float64
#  184  Payment:4.outstanding_balance                                                 float64
#  185  Payment:4.outstanding_balance_without_expense                                 float64
#  186  Payment:4.outstanding_balance_without_penalty                                 float64
#  187  Payment:5.start                                                               float64
#  188  Payment:5.totalPaymentAmount                                                  float64
#  189  Payment:5.lifecycle:transition                                                object
#  190  Payment:5.paymentAmount                                                       float64
#  191  Payment:5.amount::last                                                        float64
#  192  Payment:5.amount::min                                                         float64
#  193  Payment:5.paymentAmount::sum                                                  float64
#  194  Payment:5.dismissal::last                                                     object
#  195  Payment:5.expense::sum                                                        float64
#  196  Payment:5.outstanding_balance                                                 float64
#  197  Payment:5.outstanding_balance_without_expense                                 float64
#  198  Payment:5.outstanding_balance_without_penalty                                 float64
#  199  Payment:6.start                                                               float64
#  200  Payment:6.totalPaymentAmount                                                  float64
#  201  Payment:6.lifecycle:transition                                                object
#  202  Payment:6.paymentAmount                                                       float64
#  203  Payment:6.amount::last                                                        float64
#  204  Payment:6.amount::min                                                         float64
#  205  Payment:6.paymentAmount::sum                                                  float64
#  206  Payment:6.dismissal::last                                                     object
#  207  Payment:6.expense::sum                                                        float64
#  208  Payment:6.outstanding_balance                                                 float64
#  209  Payment:6.outstanding_balance_without_expense                                 float64
#  210  Payment:6.outstanding_balance_without_penalty                                 float64
#  211  Payment:7.start                                                               float64
#  212  Payment:7.totalPaymentAmount                                                  float64
#  213  Payment:7.lifecycle:transition                                                object
#  214  Payment:7.paymentAmount                                                       float64
#  215  Payment:7.amount::last                                                        float64
#  216  Payment:7.amount::min                                                         float64
#  217  Payment:7.paymentAmount::sum                                                  float64
#  218  Payment:7.dismissal::last                                                     object
#  219  Payment:7.expense::sum                                                        float64
#  220  Payment:7.outstanding_balance                                                 float64
#  221  Payment:7.outstanding_balance_without_expense                                 float64
#  222  Payment:7.outstanding_balance_without_penalty                                 float64
#  223  Payment:8.start                                                               float64
#  224  Payment:8.totalPaymentAmount                                                  float64
#  225  Payment:8.lifecycle:transition                                                object
#  226  Payment:8.paymentAmount                                                       float64
#  227  Payment:8.amount::last                                                        float64
#  228  Payment:8.amount::min                                                         float64
#  229  Payment:8.paymentAmount::sum                                                  float64
#  230  Payment:8.dismissal::last                                                     object
#  231  Payment:8.expense::sum                                                        float64
#  232  Payment:8.outstanding_balance                                                 float64
#  233  Payment:8.outstanding_balance_without_expense                                 float64
#  234  Payment:8.outstanding_balance_without_penalty                                 float64
#  235  Payment:9.start                                                               float64
#  236  Payment:9.totalPaymentAmount                                                  float64
#  237  Payment:9.lifecycle:transition                                                object
#  238  Payment:9.paymentAmount                                                       float64
#  239  Payment:9.amount::last                                                        float64
#  240  Payment:9.amount::min                                                         float64
#  241  Payment:9.paymentAmount::sum                                                  float64
#  242  Payment:9.dismissal::last                                                     object
#  243  Payment:9.expense::sum                                                        float64
#  244  Payment:9.outstanding_balance                                                 float64
#  245  Payment:9.outstanding_balance_without_expense                                 float64
#  246  Payment:9.outstanding_balance_without_penalty                                 float64
#  247  Payment:10.start                                                              float64
#  248  Payment:10.totalPaymentAmount                                                 float64
#  249  Payment:10.lifecycle:transition                                               object
#  250  Payment:10.paymentAmount                                                      float64
#  251  Payment:10.amount::last                                                       float64
#  252  Payment:10.amount::min                                                        float64
#  253  Payment:10.paymentAmount::sum                                                 float64
#  254  Payment:10.dismissal::last                                                    object
#  255  Payment:10.expense::sum                                                       float64
#  256  Payment:10.outstanding_balance                                                float64
#  257  Payment:10.outstanding_balance_without_expense                                float64
#  258  Payment:10.outstanding_balance_without_penalty                                float64
#  259  Payment:11.start                                                              float64
#  260  Payment:11.totalPaymentAmount                                                 float64
#  261  Payment:11.lifecycle:transition                                               object
#  262  Payment:11.paymentAmount                                                      float64
#  263  Payment:11.amount::last                                                       float64
#  264  Payment:11.amount::min                                                        float64
#  265  Payment:11.paymentAmount::sum                                                 float64
#  266  Payment:11.dismissal::last                                                    object
#  267  Payment:11.expense::sum                                                       float64
#  268  Payment:11.outstanding_balance                                                float64
#  269  Payment:11.outstanding_balance_without_expense                                float64
#  270  Payment:11.outstanding_balance_without_penalty                                float64
#  271  Payment:12.start                                                              float64
#  272  Payment:12.totalPaymentAmount                                                 float64
#  273  Payment:12.lifecycle:transition                                               object
#  274  Payment:12.paymentAmount                                                      float64
#  275  Payment:12.amount::last                                                       float64
#  276  Payment:12.amount::min                                                        float64
#  277  Payment:12.paymentAmount::sum                                                 float64
#  278  Payment:12.dismissal::last                                                    object
#  279  Payment:12.expense::sum                                                       float64
#  280  Payment:12.outstanding_balance                                                float64
#  281  Payment:12.outstanding_balance_without_expense                                float64
#  282  Payment:12.outstanding_balance_without_penalty                                float64
#  283  Payment:13.start                                                              float64
#  284  Payment:13.totalPaymentAmount                                                 float64
#  285  Payment:13.lifecycle:transition                                               object
#  286  Payment:13.paymentAmount                                                      float64
#  287  Payment:13.amount::last                                                       float64
#  288  Payment:13.amount::min                                                        float64
#  289  Payment:13.paymentAmount::sum                                                 float64
#  290  Payment:13.dismissal::last                                                    object
#  291  Payment:13.expense::sum                                                       float64
#  292  Payment:13.outstanding_balance                                                float64
#  293  Payment:13.outstanding_balance_without_expense                                float64
#  294  Payment:13.outstanding_balance_without_penalty                                float64
#  295  Payment:14.start                                                              float64
#  296  Payment:14.totalPaymentAmount                                                 float64
#  297  Payment:14.lifecycle:transition                                               object
#  298  Payment:14.paymentAmount                                                      float64
#  299  Payment:14.amount::last                                                       float64
#  300  Payment:14.amount::min                                                        float64
#  301  Payment:14.paymentAmount::sum                                                 float64
#  302  Payment:14.dismissal::last                                                    object
#  303  Payment:14.expense::sum                                                       float64
#  304  Payment:14.outstanding_balance                                                float64
#  305  Payment:14.outstanding_balance_without_expense                                float64
#  306  Payment:14.outstanding_balance_without_penalty                                float64
#  307  Payment:15.start                                                              float64
#  308  Payment:15.totalPaymentAmount                                                 float64
#  309  Payment:15.lifecycle:transition                                               object
#  310  Payment:15.paymentAmount                                                      float64
#  311  Payment:15.amount::last                                                       float64
#  312  Payment:15.amount::min                                                        float64
#  313  Payment:15.paymentAmount::sum                                                 float64
#  314  Payment:15.dismissal::last                                                    object
#  315  Payment:15.expense::sum                                                       float64
#  316  Payment:15.outstanding_balance                                                float64
#  317  Payment:15.outstanding_balance_without_expense                                float64
#  318  Payment:15.outstanding_balance_without_penalty                                float64
#  319  Send for Credit Collection:Appeal to Judge.delay                              float64
#  320  Send for Credit Collection:Notify Result Appeal to Offender.delay             float64
#  321  Send for Credit Collection:Receive Result Appeal from Prefecture.delay        float64
#  322  Send for Credit Collection:Send Appeal to Prefecture.delay                    float64
#  323  Send for Credit Collection:Insert Date Appeal to Prefecture.delay             float64
#  324  Send for Credit Collection:Add penalty.delay                                  float64
#  325  Send for Credit Collection:Insert Fine Notification.delay                     float64
#  326  Send for Credit Collection:Send Fine.delay                                    float64
#  327  Send for Credit Collection:Payment.delay                                      float64
#  328  Send for Credit Collection:Create Fine.delay                                  float64
#  329  Appeal to Judge:Notify Result Appeal to Offender.delay                        float64
#  330  Appeal to Judge:Receive Result Appeal from Prefecture.delay                   float64
#  331  Appeal to Judge:Send Appeal to Prefecture.delay                               float64
#  332  Appeal to Judge:Insert Date Appeal to Prefecture.delay                        float64
#  333  Appeal to Judge:Add penalty.delay                                             float64
#  334  Appeal to Judge:Insert Fine Notification.delay                                float64
#  335  Appeal to Judge:Send Fine.delay                                               float64
#  336  Appeal to Judge:Payment.delay                                                 float64
#  337  Appeal to Judge:Create Fine.delay                                             float64
#  338  Notify Result Appeal to Offender:Receive Result Appeal from Prefecture.delay  float64
#  339  Notify Result Appeal to Offender:Send Appeal to Prefecture.delay              float64
#  340  Notify Result Appeal to Offender:Insert Date Appeal to Prefecture.delay       float64
#  341  Notify Result Appeal to Offender:Add penalty.delay                            float64
#  342  Notify Result Appeal to Offender:Insert Fine Notification.delay               float64
#  343  Notify Result Appeal to Offender:Send Fine.delay                              float64
#  344  Notify Result Appeal to Offender:Payment.delay                                float64
#  345  Notify Result Appeal to Offender:Create Fine.delay                            float64
#  346  Receive Result Appeal from Prefecture:Send Appeal to Prefecture.delay         float64
#  347  Receive Result Appeal from Prefecture:Insert Date Appeal to Prefecture.delay  float64
#  348  Receive Result Appeal from Prefecture:Add penalty.delay                       float64
#  349  Receive Result Appeal from Prefecture:Insert Fine Notification.delay          float64
#  350  Receive Result Appeal from Prefecture:Send Fine.delay                         float64
#  351  Receive Result Appeal from Prefecture:Payment.delay                           float64
#  352  Receive Result Appeal from Prefecture:Create Fine.delay                       float64
#  353  Send Appeal to Prefecture:Insert Date Appeal to Prefecture.delay              float64
#  354  Send Appeal to Prefecture:Add penalty.delay                                   float64
#  355  Send Appeal to Prefecture:Insert Fine Notification.delay                      float64
#  356  Send Appeal to Prefecture:Send Fine.delay                                     float64
#  357  Send Appeal to Prefecture:Payment.delay                                       float64
#  358  Send Appeal to Prefecture:Create Fine.delay                                   float64
#  359  Insert Date Appeal to Prefecture:Add penalty.delay                            float64
#  360  Insert Date Appeal to Prefecture:Insert Fine Notification.delay               float64
#  361  Insert Date Appeal to Prefecture:Send Fine.delay                              float64
#  362  Insert Date Appeal to Prefecture:Payment.delay                                float64
#  363  Insert Date Appeal to Prefecture:Create Fine.delay                            float64
#  364  Add penalty:Insert Fine Notification.delay                                    float64
#  365  Add penalty:Send Fine.delay                                                   float64
#  366  Add penalty:Payment.delay                                                     float64
#  367  Add penalty:Create Fine.delay                                                 float64
#  368  Insert Fine Notification:Send Fine.delay                                      float64
#  369  Insert Fine Notification:Payment.delay                                        float64
#  370  Insert Fine Notification:Create Fine.delay                                    float64
#  371  Send Fine:Payment.delay                                                       float64
#  372  Send Fine:Create Fine.delay                                                   float64
#  373  Payment:Create Fine.delay                                                     float64
#  374  paid_full                                                                     bool
#  375  dismissed                                                                     bool
#  376  credit_collection                                                             bool
#  377  unresolved                                                                    bool
#  378  appeal                                                                        bool
#  379  overturned_judge                                                              bool
#  380  overturned_prefecture                                                         bool
#  381  overturned                                                                    bool
#  382  upheld                                                                        bool
# dtypes: bool(9), datetime64[ns](1), float64(307), int64(5), object(61)
# memory usage: 430.4+ MB

# %%
output_file_name = 'cases_' + INPUT_FILE_NAME
out_df.to_csv(output_file_name, index=False)
print(len(out_df), 'cases written to', output_file_name)
# Out:
# 150370 cases written to cases_rtfm_full.csv

# %% [markdown]
# ## 4. Verification (optional)

# %%
# uncomment below for verification 0

# print(out_df['verify_0'].value_counts())
# v_df = out_df[out_df['verify_0'] == False]
# v_df[['case_id', 'Final.totalPaymentAmount::max', 'Final.paymentAmount::sum']].head()

# %%
# uncomment below for verification 1

# print(out_df['verify_1'].value_counts())
